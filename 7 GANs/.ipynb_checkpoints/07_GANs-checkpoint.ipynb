# %% [markdown]
# # Generative Adversarial Networks (GANs) in PyTorch

# %% [markdown]
# ## Downloading and Exploring the Data

# %%
import os
import torch 
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torch.nn as nn
from IPython.display import Image
from torchvision.utils import save_image
import cv2
from IPython.display import FileLink

# %%
mnist = MNIST(root = "/data",
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %%
img, label = mnist[0]
print("Label: ", label)
print(img[:, 10:15, 10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %%
def denorms(x):
    out = (x+1)/2
    return out.clamp(0, 1)

# %%
img_norm = denorms(img)
plt.imshow(img_norm[0], cmap="gray")
print("Label: ", label)
# Out:
# Label:  5

# %%
batch_size = 100

data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img, label in data_loader:
    print("first batch")
    print(img.shape)
    print(label)
    plt.imshow(img[0][0], cmap="gray")
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([6, 7, 2, 7, 0, 2, 2, 3, 6, 1, 3, 0, 7, 5, 9, 2, 2, 3, 4, 4, 2, 3, 1, 0,
#         3, 2, 1, 4, 3, 3, 6, 9, 1, 4, 6, 6, 0, 5, 7, 2, 6, 3, 4, 2, 9, 3, 8, 3,
#         7, 0, 2, 9, 0, 9, 3, 2, 6, 7, 4, 8, 5, 2, 2, 1, 0, 2, 9, 4, 1, 3, 3, 3,
#         2, 8, 6, 9, 9, 9, 9, 2, 3, 6, 1, 6, 8, 7, 4, 3, 8, 1, 8, 1, 7, 6, 3, 8,
#         2, 8, 6, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Discrminator Network

# %%
image_size = 784
hidden_state = 256

# %%
D = nn.Sequential(
    nn.Linear(image_size, hidden_state),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_state, hidden_state),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_state, 1),
    nn.Sigmoid())

# %%
D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
latent_size = 64

# %%
G = nn.Sequential(
    nn.Linear(latent_size, hidden_state),
    nn.ReLU(),
    nn.Linear(hidden_state, hidden_state),
    nn.ReLU(),
    nn.Linear(hidden_state, image_size),
    nn.Tanh())

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorms(y.reshape((-1, 28, 28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap="gray")

# %%
plt.imshow(gen_imgs[1], cmap="gray")

# %%
G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %% [markdown]
# ## Discriminator Training

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    #Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for the fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    #Combine losses
    d_loss = d_loss_real + d_loss_fake
    #Reset Gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# ## Generator Training

# %%
z = torch.randn(batch_size, latent_size).to(device)
fake_image = G(z)
D(fake_image)
# Out:
# tensor([[0.5196],
#         [0.5186],
#         [0.5166],
#         [0.5141],
#         [0.5157],
#         [0.5158],
#         [0.5186],
#         [0.5207],
#         [0.5189],
#         [0.5190],
#         [0.5180],
#         [0.5167],
#         [0.5197],
#         [0.5163],
#         [0.5183],
#         [0.5159],
#         [0.5198],
#         [0.5171],
#         [0.5184],
#         [0.5152],
#         [0.5148],
#         [0.5176],
#         [0.5164],
#         [0.5184],
#         [0.5166],
#         [0.5185],
#         [0.5194],
#         [0.5162],
#         [0.5191],
#         [0.5166],
#         [0.5191],
#         [0.5154],
#         [0.5201],
#         [0.5172],
#         [0.5184],
#         [0.5179],
#         [0.5217],
#         [0.5164],
#         [0.5163],
#         [0.5182],
#         [0.5185],
#         [0.5184],
#         [0.5173],
#         [0.5175],
#         [0.5174],
#         [0.5169],
#         [0.5185],
#         [0.5174],
#         [0.5166],
#         [0.5163],
#         [0.5177],
#         [0.5154],
#         [0.5192],
#         [0.5185],
#         [0.5182],
#         [0.5172],
#         [0.5162],
#         [0.5182],
#         [0.5183],
#         [0.5175],
#         [0.5169],
#         [0.5156],
#         [0.5189],
#         [0.5147],
#         [0.5201],
#         [0.5160],
#         [0.5174],
#         [0.5188],
#         [0.5187],
#         [0.5170],
#         [0.5153],
#         [0.5194],
#         [0.5204],
#         [0.5172],
#         [0.5184],
#         [0.5200],
#         [0.5166],
#         [0.5180],
#         [0.5178],
#         [0.5171],
#         [0.5152],
#         [0.5201],
#         [0.5165],
#         [0.5159],
#         [0.5186],
#         [0.5160],
#         [0.5136],
#         [0.5149],
#         [0.5180],
#         [0.5168],
#         [0.5183],
#         [0.5176],
#         [0.5190],
#         [0.5172],
#         [0.5136],
#         [0.5171],
#         [0.5165],
#         [0.5183],
#         [0.5172],
#         [0.5168]], device='cuda:0', grad_fn=<SigmoidBackward0>)

# %%
def train_generator():
    # Generate fake image and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_image = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_image), labels)

    #Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_image

# %% [markdown]
# ## Training the Model

# %%
sample_dir = "samples"
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorms(images), os.path.join(sample_dir, "real_images.png"), nrow=10)
    break

Image(os.path.join(sample_dir, "real_images.png"))

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = "fake_images-{0:0=4d}.png".format(index)
    print("Saving", fake_fname)
    save_image(denorms(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

#Before training
save_fake_images(0)
Image(os.path.join(sample_dir, "fake_images-0000.png"))
# Out:
# Saving fake_images-0000.png

# %%
# %time

epochs = 50
total_steps = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        #Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print("Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(x)): {:.2f}"
                  .format(epoch, num_epochs, i+1, total_steps, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Epoch [0/50], Step [200/600], d_loss: 0.0584, g_loss: 5.1438, D(x): 0.98, D(G(x)): 0.04
# Epoch [0/50], Step [400/600], d_loss: 0.0515, g_loss: 5.1325, D(x): 0.98, D(G(x)): 0.03
# Epoch [0/50], Step [600/600], d_loss: 0.0967, g_loss: 5.2462, D(x): 0.99, D(G(x)): 0.07
# Saving fake_images-0001.png
# Epoch [1/50], Step [200/600], d_loss: 0.1070, g_loss: 5.4047, D(x): 0.97, D(G(x)): 0.05
# Epoch [1/50], Step [400/600], d_loss: 0.5403, g_loss: 4.4142, D(x): 0.92, D(G(x)): 0.25
# Epoch [1/50], Step [600/600], d_loss: 0.7139, g_loss: 4.4923, D(x): 0.78, D(G(x)): 0.17
# Saving fake_images-0002.png
# Epoch [2/50], Step [200/600], d_loss: 1.0034, g_loss: 2.2604, D(x): 0.76, D(G(x)): 0.37
# Epoch [2/50], Step [400/600], d_loss: 0.4635, g_loss: 2.9895, D(x): 0.88, D(G(x)): 0.19
# Epoch [2/50], Step [600/600], d_loss: 0.3069, g_loss: 3.9016, D(x): 0.89, D(G(x)): 0.11
# Saving fake_images-0003.png
# Epoch [3/50], Step [200/600], d_loss: 1.2682, g_loss: 2.9872, D(x): 0.68, D(G(x)): 0.39
# Epoch [3/50], Step [400/600], d_loss: 0.2756, g_loss: 3.2094, D(x): 0.90, D(G(x)): 0.10
# Epoch [3/50], Step [600/600], d_loss: 0.6334, g_loss: 3.6413, D(x): 0.81, D(G(x)): 0.24
# Saving fake_images-0004.png
# Epoch [4/50], Step [200/600], d_loss: 0.8694, g_loss: 2.1212, D(x): 0.71, D(G(x)): 0.23
# Epoch [4/50], Step [400/600], d_loss: 0.8684, g_loss: 2.7820, D(x): 0.72, D(G(x)): 0.19
# Epoch [4/50], Step [600/600], d_loss: 0.4422, g_loss: 2.8796, D(x): 0.87, D(G(x)): 0.19
# Saving fake_images-0005.png
# Epoch [5/50], Step [200/600], d_loss: 2.0818, g_loss: 1.3572, D(x): 0.65, D(G(x)): 0.62
# Epoch [5/50], Step [400/600], d_loss: 0.6788, g_loss: 1.9700, D(x): 0.81, D(G(x)): 0.25
# Epoch [5/50], Step [600/600], d_loss: 0.9452, g_loss: 2.2349, D(x): 0.84, D(G(x)): 0.40
# Saving fake_images-0006.png
# Epoch [6/50], Step [200/600], d_loss: 0.4117, g_loss: 2.6276, D(x): 0.86, D(G(x)): 0.13
# Epoch [6/50], Step [400/600], d_loss: 0.5086, g_loss: 2.0696, D(x): 0.86, D(G(x)): 0.20
# Epoch [6/50], Step [600/600], d_loss: 0.3513, g_loss: 2.7493, D(x): 0.90, D(G(x)): 0.09
# Saving fake_images-0007.png
# Epoch [7/50], Step [200/600], d_loss: 0.3809, g_loss: 4.5692, D(x): 0.83, D(G(x)): 0.03
# Epoch [7/50], Step [400/600], d_loss: 0.2132, g_loss: 3.9433, D(x): 0.91, D(G(x)): 0.07
# Epoch [7/50], Step [600/600], d_loss: 0.2813, g_loss: 2.7853, D(x): 0.91, D(G(x)): 0.08
# Saving fake_images-0008.png
# Epoch [8/50], Step [200/600], d_loss: 0.3530, g_loss: 2.0989, D(x): 0.91, D(G(x)): 0.15
# Epoch [8/50], Step [400/600], d_loss: 0.0984, g_loss: 4.3021, D(x): 0.98, D(G(x)): 0.06
# Epoch [8/50], Step [600/600], d_loss: 0.1474, g_loss: 5.4801, D(x): 0.95, D(G(x)): 0.01
# Saving fake_images-0009.png
# Epoch [9/50], Step [200/600], d_loss: 0.2879, g_loss: 4.2541, D(x): 0.92, D(G(x)): 0.09
# Epoch [9/50], Step [400/600], d_loss: 0.3289, g_loss: 2.3471, D(x): 0.91, D(G(x)): 0.13
# Epoch [9/50], Step [600/600], d_loss: 0.6101, g_loss: 4.3067, D(x): 0.86, D(G(x)): 0.14
# Saving fake_images-0010.png
# Epoch [10/50], Step [200/600], d_loss: 0.2866, g_loss: 2.9062, D(x): 0.92, D(G(x)): 0.07
# Epoch [10/50], Step [400/600], d_loss: 0.7955, g_loss: 3.5533, D(x): 0.79, D(G(x)): 0.22
# Epoch [10/50], Step [600/600], d_loss: 0.2088, g_loss: 3.5259, D(x): 0.96, D(G(x)): 0.12
# Saving fake_images-0011.png
# Epoch [11/50], Step [200/600], d_loss: 0.4574, g_loss: 3.2472, D(x): 0.84, D(G(x)): 0.09
# Epoch [11/50], Step [400/600], d_loss: 0.4698, g_loss: 4.0224, D(x): 0.84, D(G(x)): 0.10
# Epoch [11/50], Step [600/600], d_loss: 0.2770, g_loss: 4.0746, D(x): 0.94, D(G(x)): 0.12
# Saving fake_images-0012.png
# Epoch [12/50], Step [200/600], d_loss: 0.3998, g_loss: 3.3670, D(x): 0.95, D(G(x)): 0.19
# Epoch [12/50], Step [400/600], d_loss: 0.1923, g_loss: 5.3143, D(x): 0.95, D(G(x)): 0.09
# Epoch [12/50], Step [600/600], d_loss: 0.2277, g_loss: 5.9749, D(x): 0.94, D(G(x)): 0.04
# Saving fake_images-0013.png
# Epoch [13/50], Step [200/600], d_loss: 0.1264, g_loss: 4.6538, D(x): 0.97, D(G(x)): 0.06
# Epoch [13/50], Step [400/600], d_loss: 0.3544, g_loss: 3.4124, D(x): 0.90, D(G(x)): 0.09
# Epoch [13/50], Step [600/600], d_loss: 0.2305, g_loss: 4.3332, D(x): 0.91, D(G(x)): 0.07
# Saving fake_images-0014.png
# Epoch [14/50], Step [200/600], d_loss: 0.3125, g_loss: 3.9355, D(x): 0.92, D(G(x)): 0.07
# Epoch [14/50], Step [400/600], d_loss: 0.3912, g_loss: 4.6584, D(x): 0.89, D(G(x)): 0.07
# Epoch [14/50], Step [600/600], d_loss: 0.3525, g_loss: 3.4181, D(x): 0.92, D(G(x)): 0.17
# Saving fake_images-0015.png
# Epoch [15/50], Step [200/600], d_loss: 0.2845, g_loss: 3.8961, D(x): 0.89, D(G(x)): 0.03
# Epoch [15/50], Step [400/600], d_loss: 0.5818, g_loss: 4.0161, D(x): 0.84, D(G(x)): 0.06
# Epoch [15/50], Step [600/600], d_loss: 0.2591, g_loss: 6.3048, D(x): 0.92, D(G(x)): 0.04
# Saving fake_images-0016.png
# Epoch [16/50], Step [200/600], d_loss: 0.3162, g_loss: 5.2399, D(x): 0.89, D(G(x)): 0.04
# Epoch [16/50], Step [400/600], d_loss: 0.2335, g_loss: 5.6945, D(x): 0.93, D(G(x)): 0.06
# Epoch [16/50], Step [600/600], d_loss: 0.3349, g_loss: 4.3663, D(x): 0.92, D(G(x)): 0.12
# Saving fake_images-0017.png
# Epoch [17/50], Step [200/600], d_loss: 0.3437, g_loss: 3.7672, D(x): 0.92, D(G(x)): 0.16
# Epoch [17/50], Step [400/600], d_loss: 0.2794, g_loss: 3.0817, D(x): 0.92, D(G(x)): 0.13
# Epoch [17/50], Step [600/600], d_loss: 0.2108, g_loss: 4.0233, D(x): 0.96, D(G(x)): 0.13
# Saving fake_images-0018.png
# Epoch [18/50], Step [200/600], d_loss: 0.3681, g_loss: 4.7468, D(x): 0.91, D(G(x)): 0.08
# Epoch [18/50], Step [400/600], d_loss: 0.2500, g_loss: 5.6010, D(x): 0.92, D(G(x)): 0.07
# Epoch [18/50], Step [600/600], d_loss: 0.1210, g_loss: 5.4410, D(x): 0.97, D(G(x)): 0.07
# Saving fake_images-0019.png
# Epoch [19/50], Step [200/600], d_loss: 0.2634, g_loss: 3.4154, D(x): 0.92, D(G(x)): 0.08
# Epoch [19/50], Step [400/600], d_loss: 0.3952, g_loss: 3.8665, D(x): 0.98, D(G(x)): 0.25
# Epoch [19/50], Step [600/600], d_loss: 0.3539, g_loss: 3.8685, D(x): 0.94, D(G(x)): 0.13
# Saving fake_images-0020.png
# Epoch [20/50], Step [200/600], d_loss: 0.5670, g_loss: 4.1999, D(x): 0.90, D(G(x)): 0.17
# Epoch [20/50], Step [400/600], d_loss: 0.4416, g_loss: 3.3238, D(x): 0.87, D(G(x)): 0.12
# Epoch [20/50], Step [600/600], d_loss: 0.2059, g_loss: 4.0000, D(x): 0.92, D(G(x)): 0.06
# Saving fake_images-0021.png
# Epoch [21/50], Step [200/600], d_loss: 0.1931, g_loss: 4.3356, D(x): 0.96, D(G(x)): 0.11
# Epoch [21/50], Step [400/600], d_loss: 0.2312, g_loss: 2.9880, D(x): 0.94, D(G(x)): 0.11
# Epoch [21/50], Step [600/600], d_loss: 0.3416, g_loss: 3.8223, D(x): 0.91, D(G(x)): 0.10
# Saving fake_images-0022.png
# Epoch [22/50], Step [200/600], d_loss: 0.4834, g_loss: 4.1657, D(x): 0.89, D(G(x)): 0.10
# Epoch [22/50], Step [400/600], d_loss: 0.3874, g_loss: 5.2387, D(x): 0.94, D(G(x)): 0.14
# Epoch [22/50], Step [600/600], d_loss: 0.2460, g_loss: 4.6947, D(x): 0.97, D(G(x)): 0.13
# Saving fake_images-0023.png
# Epoch [23/50], Step [200/600], d_loss: 0.3770, g_loss: 5.3935, D(x): 0.86, D(G(x)): 0.03
# Epoch [23/50], Step [400/600], d_loss: 0.2865, g_loss: 3.7431, D(x): 0.92, D(G(x)): 0.08
# Epoch [23/50], Step [600/600], d_loss: 0.2788, g_loss: 4.3550, D(x): 0.91, D(G(x)): 0.04
# Saving fake_images-0024.png
# Epoch [24/50], Step [200/600], d_loss: 0.3189, g_loss: 4.8753, D(x): 0.92, D(G(x)): 0.10
# Epoch [24/50], Step [400/600], d_loss: 0.1902, g_loss: 5.0853, D(x): 0.92, D(G(x)): 0.06
# Epoch [24/50], Step [600/600], d_loss: 0.3334, g_loss: 2.9941, D(x): 0.89, D(G(x)): 0.09
# Saving fake_images-0025.png
# Epoch [25/50], Step [200/600], d_loss: 0.3537, g_loss: 5.0547, D(x): 0.93, D(G(x)): 0.14
# Epoch [25/50], Step [400/600], d_loss: 0.2294, g_loss: 4.7114, D(x): 0.94, D(G(x)): 0.11
# Epoch [25/50], Step [600/600], d_loss: 0.2657, g_loss: 3.8704, D(x): 0.94, D(G(x)): 0.12
# Saving fake_images-0026.png
# Epoch [26/50], Step [200/600], d_loss: 0.3758, g_loss: 2.9803, D(x): 0.89, D(G(x)): 0.07
# Epoch [26/50], Step [400/600], d_loss: 0.4174, g_loss: 4.4358, D(x): 0.87, D(G(x)): 0.06
# Epoch [26/50], Step [600/600], d_loss: 0.3566, g_loss: 3.5599, D(x): 0.85, D(G(x)): 0.06
# Saving fake_images-0027.png
# Epoch [27/50], Step [200/600], d_loss: 0.2354, g_loss: 3.9352, D(x): 0.96, D(G(x)): 0.13
# Epoch [27/50], Step [400/600], d_loss: 0.6505, g_loss: 3.9885, D(x): 0.80, D(G(x)): 0.09
# Epoch [27/50], Step [600/600], d_loss: 0.2832, g_loss: 3.1245, D(x): 0.93, D(G(x)): 0.13
# Saving fake_images-0028.png
# Epoch [28/50], Step [200/600], d_loss: 0.4968, g_loss: 2.7936, D(x): 0.89, D(G(x)): 0.16
# Epoch [28/50], Step [400/600], d_loss: 0.5479, g_loss: 3.1429, D(x): 0.82, D(G(x)): 0.10
# Epoch [28/50], Step [600/600], d_loss: 0.4201, g_loss: 5.0844, D(x): 0.88, D(G(x)): 0.12
# Saving fake_images-0029.png
# Epoch [29/50], Step [200/600], d_loss: 0.5955, g_loss: 2.4747, D(x): 0.84, D(G(x)): 0.21
# Epoch [29/50], Step [400/600], d_loss: 0.5109, g_loss: 2.9619, D(x): 0.84, D(G(x)): 0.10
# Epoch [29/50], Step [600/600], d_loss: 0.3086, g_loss: 3.6341, D(x): 0.86, D(G(x)): 0.06
# Saving fake_images-0030.png
# Epoch [30/50], Step [200/600], d_loss: 0.4220, g_loss: 3.7222, D(x): 0.84, D(G(x)): 0.07
# Epoch [30/50], Step [400/600], d_loss: 0.4399, g_loss: 4.4554, D(x): 0.87, D(G(x)): 0.13
# Epoch [30/50], Step [600/600], d_loss: 0.2721, g_loss: 4.4280, D(x): 0.91, D(G(x)): 0.09
# Saving fake_images-0031.png
# Epoch [31/50], Step [200/600], d_loss: 0.3294, g_loss: 5.1615, D(x): 0.87, D(G(x)): 0.05
# Epoch [31/50], Step [400/600], d_loss: 0.3301, g_loss: 6.5897, D(x): 0.87, D(G(x)): 0.02
# Epoch [31/50], Step [600/600], d_loss: 0.4749, g_loss: 3.4407, D(x): 0.88, D(G(x)): 0.13
# Saving fake_images-0032.png
# Epoch [32/50], Step [200/600], d_loss: 0.5081, g_loss: 3.4895, D(x): 0.90, D(G(x)): 0.20
# Epoch [32/50], Step [400/600], d_loss: 0.2675, g_loss: 3.3916, D(x): 0.94, D(G(x)): 0.14
# Epoch [32/50], Step [600/600], d_loss: 0.2845, g_loss: 4.6018, D(x): 0.91, D(G(x)): 0.10
# Saving fake_images-0033.png
# Epoch [33/50], Step [200/600], d_loss: 0.3915, g_loss: 3.1300, D(x): 0.93, D(G(x)): 0.18
# Epoch [33/50], Step [400/600], d_loss: 0.4611, g_loss: 2.3154, D(x): 0.90, D(G(x)): 0.16
# Epoch [33/50], Step [600/600], d_loss: 0.3869, g_loss: 3.4244, D(x): 0.86, D(G(x)): 0.05
# Saving fake_images-0034.png
# Epoch [34/50], Step [200/600], d_loss: 0.4196, g_loss: 2.3479, D(x): 0.90, D(G(x)): 0.19
# Epoch [34/50], Step [400/600], d_loss: 0.3685, g_loss: 3.8507, D(x): 0.90, D(G(x)): 0.15
# Epoch [34/50], Step [600/600], d_loss: 0.6180, g_loss: 2.9035, D(x): 0.82, D(G(x)): 0.14
# Saving fake_images-0035.png
# Epoch [35/50], Step [200/600], d_loss: 0.6377, g_loss: 2.8879, D(x): 0.81, D(G(x)): 0.15
# Epoch [35/50], Step [400/600], d_loss: 0.4453, g_loss: 3.1689, D(x): 0.79, D(G(x)): 0.10
# Epoch [35/50], Step [600/600], d_loss: 0.4139, g_loss: 2.4412, D(x): 0.86, D(G(x)): 0.15
# Saving fake_images-0036.png
# Epoch [36/50], Step [200/600], d_loss: 0.3985, g_loss: 3.0630, D(x): 0.88, D(G(x)): 0.16
# Epoch [36/50], Step [400/600], d_loss: 0.3413, g_loss: 2.8441, D(x): 0.88, D(G(x)): 0.09
# Epoch [36/50], Step [600/600], d_loss: 0.6341, g_loss: 3.4214, D(x): 0.74, D(G(x)): 0.06
# Saving fake_images-0037.png
# Epoch [37/50], Step [200/600], d_loss: 0.3345, g_loss: 4.4956, D(x): 0.90, D(G(x)): 0.09
# Epoch [37/50], Step [400/600], d_loss: 0.2458, g_loss: 4.3245, D(x): 0.87, D(G(x)): 0.03
# Epoch [37/50], Step [600/600], d_loss: 0.5631, g_loss: 2.4255, D(x): 0.79, D(G(x)): 0.08
# Saving fake_images-0038.png
# Epoch [38/50], Step [200/600], d_loss: 0.5050, g_loss: 3.2426, D(x): 0.90, D(G(x)): 0.17
# Epoch [38/50], Step [400/600], d_loss: 0.3273, g_loss: 4.7382, D(x): 0.90, D(G(x)): 0.11
# Epoch [38/50], Step [600/600], d_loss: 0.2090, g_loss: 4.4449, D(x): 0.95, D(G(x)): 0.11
# Saving fake_images-0039.png
# Epoch [39/50], Step [200/600], d_loss: 0.3115, g_loss: 4.7822, D(x): 0.86, D(G(x)): 0.03
# Epoch [39/50], Step [400/600], d_loss: 0.2797, g_loss: 3.1745, D(x): 0.91, D(G(x)): 0.08
# Epoch [39/50], Step [600/600], d_loss: 0.2058, g_loss: 3.7764, D(x): 0.93, D(G(x)): 0.06
# Saving fake_images-0040.png
# Epoch [40/50], Step [200/600], d_loss: 0.7324, g_loss: 2.7401, D(x): 0.96, D(G(x)): 0.34
# Epoch [40/50], Step [400/600], d_loss: 0.6585, g_loss: 2.9596, D(x): 0.78, D(G(x)): 0.12
# Epoch [40/50], Step [600/600], d_loss: 0.3803, g_loss: 3.0018, D(x): 0.89, D(G(x)): 0.15
# Saving fake_images-0041.png
# Epoch [41/50], Step [200/600], d_loss: 0.5961, g_loss: 1.8946, D(x): 0.82, D(G(x)): 0.19
# Epoch [41/50], Step [400/600], d_loss: 0.4722, g_loss: 2.6527, D(x): 0.86, D(G(x)): 0.12
# Epoch [41/50], Step [600/600], d_loss: 0.4257, g_loss: 1.8693, D(x): 0.93, D(G(x)): 0.23
# Saving fake_images-0042.png
# Epoch [42/50], Step [200/600], d_loss: 0.5722, g_loss: 2.1165, D(x): 0.86, D(G(x)): 0.21
# Epoch [42/50], Step [400/600], d_loss: 0.5659, g_loss: 3.3548, D(x): 0.82, D(G(x)): 0.16
# Epoch [42/50], Step [600/600], d_loss: 0.5183, g_loss: 2.8475, D(x): 0.85, D(G(x)): 0.16
# Saving fake_images-0043.png
# Epoch [43/50], Step [200/600], d_loss: 0.6250, g_loss: 2.8420, D(x): 0.80, D(G(x)): 0.18
# Epoch [43/50], Step [400/600], d_loss: 0.5745, g_loss: 3.4357, D(x): 0.80, D(G(x)): 0.08
# Epoch [43/50], Step [600/600], d_loss: 0.5068, g_loss: 3.0379, D(x): 0.82, D(G(x)): 0.13
# Saving fake_images-0044.png
# Epoch [44/50], Step [200/600], d_loss: 0.5658, g_loss: 2.5249, D(x): 0.90, D(G(x)): 0.24
# Epoch [44/50], Step [400/600], d_loss: 0.5055, g_loss: 3.5320, D(x): 0.82, D(G(x)): 0.10
# Epoch [44/50], Step [600/600], d_loss: 0.7373, g_loss: 2.2508, D(x): 0.74, D(G(x)): 0.18
# Saving fake_images-0045.png
# Epoch [45/50], Step [200/600], d_loss: 0.6319, g_loss: 1.8726, D(x): 0.87, D(G(x)): 0.26
# Epoch [45/50], Step [400/600], d_loss: 0.6000, g_loss: 2.4628, D(x): 0.74, D(G(x)): 0.09
# Epoch [45/50], Step [600/600], d_loss: 0.5774, g_loss: 2.7490, D(x): 0.83, D(G(x)): 0.19
# Saving fake_images-0046.png
# Epoch [46/50], Step [200/600], d_loss: 0.5782, g_loss: 2.5164, D(x): 0.87, D(G(x)): 0.23
# Epoch [46/50], Step [400/600], d_loss: 0.4845, g_loss: 2.4865, D(x): 0.92, D(G(x)): 0.22
# Epoch [46/50], Step [600/600], d_loss: 0.5346, g_loss: 2.9228, D(x): 0.83, D(G(x)): 0.17
# Saving fake_images-0047.png
# Epoch [47/50], Step [200/600], d_loss: 0.5146, g_loss: 2.9350, D(x): 0.84, D(G(x)): 0.18
# Epoch [47/50], Step [400/600], d_loss: 0.5414, g_loss: 3.3749, D(x): 0.78, D(G(x)): 0.06
# Epoch [47/50], Step [600/600], d_loss: 0.5505, g_loss: 3.8535, D(x): 0.84, D(G(x)): 0.19
# Saving fake_images-0048.png
# Epoch [48/50], Step [200/600], d_loss: 0.2875, g_loss: 3.1182, D(x): 0.92, D(G(x)): 0.13
# Epoch [48/50], Step [400/600], d_loss: 0.3771, g_loss: 3.7633, D(x): 0.87, D(G(x)): 0.13
# Epoch [48/50], Step [600/600], d_loss: 0.4098, g_loss: 4.7469, D(x): 0.87, D(G(x)): 0.12
# Saving fake_images-0049.png
# Epoch [49/50], Step [200/600], d_loss: 0.4042, g_loss: 4.0568, D(x): 0.82, D(G(x)): 0.08
# Epoch [49/50], Step [400/600], d_loss: 0.5231, g_loss: 2.9971, D(x): 0.86, D(G(x)): 0.22
# Epoch [49/50], Step [600/600], d_loss: 0.4839, g_loss: 3.2193, D(x): 0.86, D(G(x)): 0.16
# Saving fake_images-0050.png

# %% [markdown]
# ## Visualize Progress

# %%
vid_fname = "gans_training.avi"

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if "fake_images" in f]
files.sort()
files
# Out:
# ['samples\\fake_images-0000.png',
#  'samples\\fake_images-0001.png',
#  'samples\\fake_images-0002.png',
#  'samples\\fake_images-0003.png',
#  'samples\\fake_images-0004.png',
#  'samples\\fake_images-0005.png',
#  'samples\\fake_images-0006.png',
#  'samples\\fake_images-0007.png',
#  'samples\\fake_images-0008.png',
#  'samples\\fake_images-0009.png',
#  'samples\\fake_images-0010.png',
#  'samples\\fake_images-0011.png',
#  'samples\\fake_images-0012.png',
#  'samples\\fake_images-0013.png',
#  'samples\\fake_images-0014.png',
#  'samples\\fake_images-0015.png',
#  'samples\\fake_images-0016.png',
#  'samples\\fake_images-0017.png',
#  'samples\\fake_images-0018.png',
#  'samples\\fake_images-0019.png',
#  'samples\\fake_images-0020.png',
#  'samples\\fake_images-0021.png',
#  'samples\\fake_images-0022.png',
#  'samples\\fake_images-0023.png',
#  'samples\\fake_images-0024.png',
#  'samples\\fake_images-0025.png',
#  'samples\\fake_images-0026.png',
#  'samples\\fake_images-0027.png',
#  'samples\\fake_images-0028.png',
#  'samples\\fake_images-0029.png',
#  'samples\\fake_images-0030.png',
#  'samples\\fake_images-0031.png',
#  'samples\\fake_images-0032.png',
#  'samples\\fake_images-0033.png',
#  'samples\\fake_images-0034.png',
#  'samples\\fake_images-0035.png',
#  'samples\\fake_images-0036.png',
#  'samples\\fake_images-0037.png',
#  'samples\\fake_images-0038.png',
#  'samples\\fake_images-0039.png',
#  'samples\\fake_images-0040.png',
#  'samples\\fake_images-0041.png',
#  'samples\\fake_images-0042.png',
#  'samples\\fake_images-0043.png',
#  'samples\\fake_images-0044.png',
#  'samples\\fake_images-0045.png',
#  'samples\\fake_images-0046.png',
#  'samples\\fake_images-0047.png',
#  'samples\\fake_images-0048.png',
#  'samples\\fake_images-0049.png',
#  'samples\\fake_images-0050.png']

# %%
out = cv2.VideoWriter(vid_fname, cv2.VideoWriter_fourcc(*"MP4V"), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink("gans_training.avi")
# Out:
# C:\Users\SHLOK\PyTorch\7 GANs\gans_training.avi

# %% [markdown]
# ## Visualizing Loss and Scores

# %%
plt.plot(d_losses, ".")
plt.plot(g_losses, ".")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(["Discriminator", "Generator"])
plt.title("Losses")
# Out:
# Text(0.5, 1.0, 'Losses')

# %%
plt.plot(real_scores, ".")
plt.plot(fake_scores, ".")
plt.xlabel("epoch")
plt.ylabel("score")
plt.legend(["Real", "Fake"])
plt.title("Scores")
# Out:
# Text(0.5, 1.0, 'Scores')
